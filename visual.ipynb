# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import os
from empiricaldist import Pmf
import ast

result_path = os.getcwd() + '/result'

# %% [markdown]
# ## Load Record

# %%
bot_record = pd.read_csv(result_path + '/bot_record.csv')
bot_record['fitnesses'] = bot_record['fitnesses'].apply(lambda x: ast.literal_eval(x))
bot_record
# Out:
#     Epoch  max_pos     max_fit       fit_sum  \
# 0       0      153  100.560773   7252.573463
# 1       1      351  119.634405  41278.012586
# 2       2      237  125.304760  41976.755852
# 3       3      332  139.024298  44327.719522
# 4       4        0  139.024298  45527.417795
# 5       5      376  151.406242  48557.541529
# 6       6        0  151.406242  48056.099264
# 7       7        0  151.406242  49241.662704
# 8       8        0  151.406242  49818.831019
# 9       9        0  151.406242  49454.006283
# 10     10        0  151.406242  49127.791394
# 11     11        0  151.406242  49841.758444
# 12     12        0  151.406242  49306.486243
# 13     13        0  151.406242  49136.014017
# 14     14        0  151.406242  49341.422205
# 15     15        0  151.406242  49136.068315
# 16     16        0  151.406242  49451.413247
# 17     17        0  151.406242  49827.822094
# 18     18        0  151.406242  49544.993733
# 19     19        0  151.406242  49874.885391
# 20     20        0  151.406242  49422.601925
# 21     21        0  151.406242  49625.031050
# 22     22        0  151.406242  49721.766985
# 23     23        0  151.406242  49836.154646
# 24     24        0  151.406242  49768.929045
# 25     25        0  151.406242  49836.856097
# 26     26        0  151.406242  49656.552389
# 27     27        0  151.406242  49455.876378
# 28     28        0  151.406242  49927.720350
# 29     29        0  151.406242  49791.070583
#
#                                             fitnesses
# 0   [100.0, 100.0, 5.8938547476260555e-06, 0.00051...
# 1   [100.560773169196, 100.0, 100.0, 100.0, 0.0009...
# 2   [119.63440537748684, 100.0, 100.0, 100.0, 100....
# 3   [125.3047597065396, 100.0, 0.00233119085255107...
# 4   [139.024298069292, 100.0, 100.0, 58.1039891230...
# 5   [139.024298069292, 100.0, 100.0, 100.0, 100.0,...
# 6   [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 7   [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 8   [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 9   [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 10  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 11  [151.40624155603382, 100.0, 100.0, 100.0, 0.00...
# 12  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 13  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 14  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 15  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 16  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 17  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 18  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 19  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 20  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 21  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 22  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 23  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 24  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 25  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 26  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 27  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 28  [151.40624155603382, 100.0, 100.0, 100.0, 100....
# 29  [151.40624155603382, 100.0, 100.0, 100.0, 100....

# %% [markdown]
# ## Fit Sum

# %%
plt.figure(figsize=(10, 5))
sns.set(font_scale=1.2)
sns.lineplot(data=bot_record, x='Epoch', y='fit_sum')
plt.show()

# %% [markdown]
# ## Max Fit

# %%
plt.figure(figsize=(10, 5))
sns.set(font_scale=1.2)
sns.lineplot(data=bot_record, x='Epoch', y='max_fit')
plt.show()

# %% [markdown]
# ## PMF

# %%
pmf_epoch_1 = Pmf.from_seq(bot_record.iloc[0]['fitnesses'])
pmf_epoch_30 = Pmf.from_seq(bot_record.iloc[29]['fitnesses'])
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
pmf_epoch_1.plot(label='Epoch 1', color='C0')
plt.xlabel('fitness')
plt.ylabel('PMF')
plt.legend()
plt.subplot(1,2,2)
pmf_epoch_30.plot(label='Epoch 30', color='C1')
plt.xlabel('fitness')
plt.ylabel('PMF')
plt.legend()
plt.show()
