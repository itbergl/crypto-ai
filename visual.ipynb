# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import os
from empiricaldist import Pmf
import ast

result_path = os.getcwd() + '/result'

# %% [markdown]
# ## Load Record

# %%
bot_record = pd.read_csv(result_path + '/bot_record.csv')
bot_record['fitnesses'] = bot_record['fitnesses'].apply(lambda x: ast.literal_eval(x))
bot_record
# Out:
#     Epoch  max_pos     max_fit       fit_sum  \
# 0       0      393  246.559616  36397.891980
# 1       1      273  246.559616  38631.793057
# 2       2        5  193.835917  44154.858109
# 3       3       82  193.835917  45720.854056
# 4       4       32  193.835917  47519.061905
# 5       5      397  235.747271  48784.473985
# 6       6      129  235.747271  48825.723415
# 7       7      317  191.846275  49333.226539
# 8       8      144  191.846275  49922.692327
# 9       9      184  207.235225  53124.349796
# 10     10      370  193.848390  53397.348776
# 11     11      401  193.848390  51498.192560
# 12     12      485  233.346650  51477.109973
# 13     13      185  193.432320  52366.888593
# 14     14      130  192.783289  52362.292592
# 15     15      126  191.846275  50765.168104
# 16     16      360  212.305499  51981.634044
# 17     17      400  229.227854  49615.618908
# 18     18      349  241.257999  49997.078278
# 19     19       74  191.846275  51459.308282
# 20     20      480  237.923212  51169.114475
# 21     21      121  234.918324  51038.554379
# 22     22      221  194.711893  50144.170190
# 23     23       93  194.711893  51089.640654
# 24     24        3  185.905102  50330.834950
# 25     25      370  185.905102  51435.016945
# 26     26      437  185.905102  50597.523717
# 27     27       84  185.905102  50952.188669
# 28     28      143  153.924532  51409.743146
# 29     29       64  136.640463  51331.009499
#
#                                             fitnesses
# 0   [110.94783729944199, 100.0, 100.0, 2.793349204...
# 1   [34.8877229098758, 66.11940265126454, 2.614903...
# 2   [112.6663759828449, 98.01807960665144, 100.0, ...
# 3   [112.24009361633443, 113.37598641722715, 100.0...
# 4   [108.90993053508255, 100.0, 87.39848809699836,...
# 5   [100.0, 134.56865021770682, 100.0, 112.6663759...
# 6   [100.0, 100.0, 100.0, 100.0, 99.43283048545076...
# 7   [93.27433687669762, 93.27433687669762, 93.8747...
# 8   [100.0, 100.0, 103.80202440614566, 98.69504271...
# 9   [93.27433687669762, 116.71626634940773, 100.0,...
# 10  [105.20618696616614, 155.57803894215266, 100.0...
# 11  [100.0, 100.0, 103.80202440614566, 100.0, 98.4...
# 12  [49.91495654436388, 100.0, 100.0, 107.97264040...
# 13  [112.24009361633443, 100.0, 171.99002673359158...
# 14  [100.0, 100.0, 100.0, 92.76597897838316, 73.44...
# 15  [150.09213863328327, 100.0, 100.0, 100.0, 69.6...
# 16  [100.0, 100.0, 100.0, 100.0, 100.0, 146.328571...
# 17  [100.0, 100.0, 100.0, 100.0, 29.11221451541813...
# 18  [103.80202440614566, 100.0, 100.0, 100.0, 100....
# 19  [112.24009361633443, 101.82845918608508, 100.0...
# 20  [100.0, 100.0, 108.25641659626783, 191.8462749...
# 21  [100.0, 78.32477746232512, 100.0, 100.0, 98.69...
# 22  [103.18050558058849, 100.0, 136.90009851416735...
# 23  [100.0, 100.0, 98.41015192507804, 100.0, 112.2...
# 24  [100.0, 103.80202440614566, 100.0, 185.9051015...
# 25  [106.67733485045088, 100.0, 105.20618696616614...
# 26  [100.0, 100.0, 105.20618696616614, 103.8020244...
# 27  [74.49019527533254, 100.0, 77.21499685660399, ...
# 28  [100.0, 103.80202440614566, 100.0, 112.7456229...
# 29  [103.80202440614566, 105.20618696616614, 112.2...

# %% [markdown]
# ## Fit Sum

# %%
plt.figure(figsize=(10, 5))
sns.set(font_scale=1.2)
sns.lineplot(data=bot_record, x='Epoch', y='fit_sum')
plt.show()

# %% [markdown]
# ## Max Fit

# %%
plt.figure(figsize=(10, 5))
sns.set(font_scale=1.2)
sns.lineplot(data=bot_record, x='Epoch', y='max_fit')
plt.show()

# %% [markdown]
# ## PMF

# %%
pmf_epoch_1 = Pmf.from_seq(bot_record.iloc[0]['fitnesses'])
pmf_epoch_30 = Pmf.from_seq(bot_record.iloc[29]['fitnesses'])
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
pmf_epoch_1.plot(label='Epoch 1', color='C0')
plt.xlabel('fitness')
plt.ylabel('PMF')
plt.legend()
plt.subplot(1,2,2)
pmf_epoch_30.plot(label='Epoch 30', color='C1')
plt.xlabel('fitness')
plt.ylabel('PMF')
plt.legend()
plt.show()
