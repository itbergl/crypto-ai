# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import os
from empiricaldist import Pmf
import ast

result_path = os.getcwd() + '/result'

# %% [markdown]
# ## Load Record

# %%
bot_record = pd.read_csv(result_path + '/bot_record.csv')
bot_record['fitnesses'] = bot_record['fitnesses'].apply(lambda x: ast.literal_eval(x))
bot_record
# Out:
#     Epoch  max_pos     max_fit       fit_sum
# 0       0       65  146.668521  14136.036149  \
# 1       1       78  171.990027  36564.197779
# 2       2        0  171.990027  42428.230481
# 3       3      409  183.799712  46326.270758
# 4       4        0  183.799712  47184.410407
# 5       5      160  264.576073  47781.890275
# 6       6        0  264.576073  48536.989655
# 7       7        0  264.576073  50667.602854
# 8       8        0  264.576073  50827.148874
# 9       9        0  264.576073  54100.178383
# 10     10        0  264.576073  56123.834768
# 11     11        0  264.576073  58208.193685
# 12     12        0  264.576073  61701.167498
# 13     13        0  264.576073  68384.618053
# 14     14        0  264.576073  72497.939105
# 15     15        0  264.576073  74682.213152
# 16     16        0  264.576073  78877.774275
# 17     17        0  264.576073  80143.986256
# 18     18        0  264.576073  80592.376131
# 19     19        0  264.576073  81035.039090
# 20     20        0  264.576073  81610.129075
# 21     21        0  264.576073  82222.724033
# 22     22        0  264.576073  83779.052559
# 23     23        0  264.576073  83906.242546
# 24     24        0  264.576073  84210.827058
# 25     25        0  264.576073  84547.304215
# 26     26        0  264.576073  83710.486907
# 27     27        0  264.576073  83981.157542
# 28     28        0  264.576073  83388.934973
# 29     29        0  264.576073  83509.852854
#
#                                             fitnesses
# 0   [4.61428734290389, 0.19427133052755918, 0.0614...
# 1   [146.66852061173566, 88.85187245156804, 100.0,...
# 2   [171.99002673359158, 100.0, 7.1598410623663975...
# 3   [171.99002673359158, 160.32385460142876, 67.61...
# 4   [183.79971216811362, 100.0, 100.0, 100.0, 100....
# 5   [183.79971216811362, 160.32385460142876, 100.0...
# 6   [264.57607330461525, 100.0, 100.0, 171.9900267...
# 7   [264.57607330461525, 100.0, 100.0, 100.0, 100....
# 8   [264.57607330461525, 100.0, 95.97199268168728,...
# 9   [264.57607330461525, 100.0, 100.0, 100.0, 97.1...
# 10  [264.57607330461525, 171.99002673359158, 100.0...
# 11  [264.57607330461525, 171.99002673359158, 4.748...
# 12  [264.57607330461525, 85.16149970947954, 171.99...
# 13  [264.57607330461525, 100.0, 100.0, 100.0, 100....
# 14  [264.57607330461525, 171.99002673359158, 171.9...
# 15  [264.57607330461525, 160.32385460142876, 100.0...
# 16  [264.57607330461525, 96.96216622056582, 160.21...
# 17  [264.57607330461525, 160.21032695239708, 160.2...
# 18  [264.57607330461525, 171.99002673359158, 171.9...
# 19  [264.57607330461525, 171.99002673359158, 171.9...
# 20  [264.57607330461525, 100.0, 160.21032695239708...
# 21  [264.57607330461525, 171.99002673359158, 171.9...
# 22  [264.57607330461525, 160.21032695239708, 171.9...
# 23  [264.57607330461525, 160.32385460142876, 171.9...
# 24  [264.57607330461525, 171.99002673359158, 171.9...
# 25  [264.57607330461525, 160.21032695239708, 171.9...
# 26  [264.57607330461525, 171.99002673359158, 160.2...
# 27  [264.57607330461525, 160.21032695239708, 171.9...
# 28  [264.57607330461525, 171.99002673359158, 171.9...
# 29  [264.57607330461525, 171.99002673359158, 171.9...

# %% [markdown]
# ## Fit Sum

# %%
plt.figure(figsize=(10, 5))
sns.set(font_scale=1.2)
sns.lineplot(data=bot_record, x='Epoch', y='fit_sum')
plt.show()

# %% [markdown]
# ## Max Fit

# %%
plt.figure(figsize=(10, 5))
sns.set(font_scale=1.2)
sns.lineplot(data=bot_record, x='Epoch', y='max_fit')
plt.show()

# %% [markdown]
# ## PMF

# %%
pmf_epoch_1 = Pmf.from_seq(bot_record.iloc[0]['fitnesses'])
pmf_epoch_30 = Pmf.from_seq(bot_record.iloc[29]['fitnesses'])
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
pmf_epoch_1.plot(label='Epoch 1', color='C0')
plt.xlabel('fitness')
plt.ylabel('PMF')
plt.legend()
plt.subplot(1,2,2)
pmf_epoch_30.plot(label='Epoch 30', color='C1')
plt.xlabel('fitness')
plt.ylabel('PMF')
plt.legend()
plt.show()
